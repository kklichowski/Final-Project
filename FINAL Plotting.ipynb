# %%
#API

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list = ["Bubble Tea", "Acaii", "Poke Bowl", "craft beer"]
pytrends.build_payload(kw_list, cat=0, timeframe='all', geo='US', gprop='')

# %%
df = pytrends.interest_over_time()

# %%
r = pytrends

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
#sns.lineplot(data=kw_list,y="Avocado", x="date")

# %%
type(pytrends.interest_over_time())
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.reset_index()

# %%
df["Country"] = "US"

# %%
df
# Out:
#           date  Bubble Tea  Acaii  Poke Bowl  craft beer  isPartial Country
# 0   2004-01-01          16      0          0           2      False      US
# 1   2004-02-01          10      1          0           1      False      US
# 2   2004-03-01          11      0          0           2      False      US
# 3   2004-04-01          18      0          0           1      False      US
# 4   2004-05-01          17      0          0           1      False      US
# ..         ...         ...    ...        ...         ...        ...     ...
# 189 2019-10-01          59      0         32          33      False      US
# 190 2019-11-01          58      0         29          33      False      US
# 191 2019-12-01          58      0         28          36      False      US
# 192 2020-01-01          65      0         37          30      False      US
# 193 2020-02-01          67      0         36          34      False      US
#
# [194 rows x 7 columns]

# %%
kw_list1 = ["Avocado", "Cupcake", "Ramen"]

# %%
countries = ["US"]

# %%
for country in countries:
    pytrends.build_payload(kw_list, cat=0, timeframe='all', geo=country, gprop='')
    df = pytrends.interest_over_time()
    df["country"] = country
    try:
        df_all = df_all.append(df, ignore=FALSE)
    except:
        df_all = df
        sleep(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-aaf4548df0f2> in <module>
#       5     try:
# ----> 6         df_all = df_all.append(df, ignore=FALSE)
#       7     except:
#
# NameError: name 'FALSE' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-aaf4548df0f2> in <module>
#       7     except:
#       8         df_all = df
# ----> 9         sleep(10)
#
# NameError: name 'sleep' is not defined

# %%
sns.lineplot(data=df ,y="Cupcake", x="date")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-895f63ef4f10> in <module>
# ----> 1 sns.lineplot(data=df ,y="Cupcake", x="date")
#
# ~/opt/miniconda3/envs/code_red/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ...

# %%
from pytrends.request import TrendReq

pytrend = TrendReq()

coun=('''AD
AE
AF
AG
AI
AL
AM
AO
AQ
AR
AS
AT
AU
AW
AX
AZ
BA
BB
BD
BE
BF
BG
BH
BI
BJ
BL
BM
BN
BO
BQ
BQ 
BR
BS
BT
BV
BW
BY
BZ
CA
CC
CD
CF
CG
CH
CI
CK
CL
CM
CN
CO
CR
CU
CV
CW
CX
CY
CZ
DE
DJ
DK
DM
DO
DZ
EC
EE
EG
EH
ER
ES
ET
FI
FJ
FK
FM
FO
FR
GA
GB
GD
GE
GF
GG
GH
GI
GL
GM
GN
GP
GQ
GR
GS
GT
GU
GW
GY
HK
HM
HN
HR
HT
HU
ID
IE
IL
IM
IN
IO
IQ
IR
IS
IT
JE
JM
JO
JP
KE
KG
KH
KI
KM
KN
KP
KR
KW
KY
KZ
LA
LB
LC
LI
LK
LR
LS
LT
LU
LV
LY
MA
MC
MD
ME
MF
MG
MH
MK
ML
MM
MN
MO
MP
MQ
MR
MS
MT
MU
MV
MW
MX
MY
MZ
NA
NC
NE
NF
NG
NI
NL
NO
NP
NR
NU
NZ
OM
PA
PE
PF
PG
PH
PK
PL
PM
PN
PR
PS
PT
PW
PY
QA
RE
RO
RS
RU
RW
SA
SB
SC
SD
SE
SG
SH
SI
SJ
SK
SL
SM
SN
SO
SR
SS
ST
SV
SX
SY
SZ
TC
TD
TF
TG
TH
TJ
TK
TL
TM
TN
TO
TR
TT
TV
TW
TZ
UA
UG
UM
US
UY
UZ
VA
VC
VE
VG
VI
VN
VU
WF
WS
YE
YT
ZA
ZM
ZW
''').split()

for country in coun:
    try:
        pytrend.build_payload(kw_list, timeframe='all', geo=country)
        interest_over_time_df = pytrend.interest_over_time()
        interest_over_time_df.to_csv(country+'_tfood2.csv')    
    except:
        continue

# %%
pd.read_csv('AU_holiday.csv')
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  isPartial
# 0    2004-01-01        6        1      6     12      False
# 1    2004-02-01        7        1      2     12      False
# 2    2004-03-01        4        0      0     13      False
# 3    2004-04-01        4        1      0     13      False
# 4    2004-05-01        4        1      2     13      False
# ..          ...      ...      ...    ...    ...        ...
# 189  2019-10-01       40       23     32     91      False
# 190  2019-11-01       35       23     33     87      False
# 191  2019-12-01       38       19     32     97      False
# 192  2020-01-01       36       16     35     98      False
# 193  2020-02-01       34       22     36     88       True
#
# [194 rows x 6 columns]

# %%
sns.lineplot(data=pd.read_csv('US_holiday.csv') ,y="Cupcake", x="date")
sns.lineplot(data=pd.read_csv('AU_holiday.csv') ,y="Cupcake", x="date")
sns.lineplot(data=pd.read_csv('FI_holiday.csv') ,y="Cupcake", x="date")
sns.lineplot(data=pd.read_csv('HU_holiday.csv') ,y="Cupcake", x="date")
