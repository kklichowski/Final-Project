# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
pd.read_csv('DE_merged2.csv')
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  isPartial_x  Bubble Tea  \
# 0    2004-01-01        4        0      1     25        False           1
# 1    2004-02-01        4        0      1     28        False           0
# 2    2004-03-01        4        1      1     27        False           0
# 3    2004-04-01        5        0      1     25        False           0
# 4    2004-05-01        3        0      1     22        False           0
# ..          ...      ...      ...    ...    ...          ...         ...
# 189  2019-10-01       28        6     18     90        False          12
# 190  2019-11-01       30        5     17     88        False           8
# 191  2019-12-01       33        4     17     93        False           9
# 192  2020-01-01       45        5     20     99        False          11
# 193  2020-02-01       46        6     17     97        False          11
#
#      Acaii  Poke Bowl  craft beer  isPartial_y
# ...

# %%
DEm = pd.read_csv('DE_merged2.csv')

# %%
DEm
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  isPartial_x  Bubble Tea  \
# 0    2004-01-01        4        0      1     25        False           1
# 1    2004-02-01        4        0      1     28        False           0
# 2    2004-03-01        4        1      1     27        False           0
# 3    2004-04-01        5        0      1     25        False           0
# 4    2004-05-01        3        0      1     22        False           0
# ..          ...      ...      ...    ...    ...          ...         ...
# 189  2019-10-01       28        6     18     90        False          12
# 190  2019-11-01       30        5     17     88        False           8
# 191  2019-12-01       33        4     17     93        False           9
# 192  2020-01-01       45        5     20     99        False          11
# 193  2020-02-01       46        6     17     97        False          11
#
#      Acaii  Poke Bowl  craft beer  isPartial_y
# ...

# %%
DEm["Country"] = "DE"

# %%
DEm
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  isPartial_x  Bubble Tea  \
# 0    2004-01-01        4        0      1     25        False           1
# 1    2004-02-01        4        0      1     28        False           0
# 2    2004-03-01        4        1      1     27        False           0
# 3    2004-04-01        5        0      1     25        False           0
# 4    2004-05-01        3        0      1     22        False           0
# ..          ...      ...      ...    ...    ...          ...         ...
# 189  2019-10-01       28        6     18     90        False          12
# 190  2019-11-01       30        5     17     88        False           8
# 191  2019-12-01       33        4     17     93        False           9
# 192  2020-01-01       45        5     20     99        False          11
# 193  2020-02-01       46        6     17     97        False          11
#
#      Acaii  Poke Bowl  craft beer  isPartial_y Country
# ...

# %%
pd.read_csv('US_merged.csv')
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  isPartial_x  Bubble Tea  \
# 0    2004-01-01        4        2      3     28        False          15
# 1    2004-02-01        4        2      2     29        False          11
# 2    2004-03-01        4        3      2     28        False          13
# 3    2004-04-01        4        2      2     28        False          15
# 4    2004-05-01        4        3      2     26        False          16
# ..          ...      ...      ...    ...    ...          ...         ...
# 189  2019-10-01       22       25     34     80        False          59
# 190  2019-11-01       21       15     37     83        False          57
# 191  2019-12-01       21       14     39     87        False          58
# 192  2020-01-01       31       14     40     93        False          65
# 193  2020-02-01       30       16     36     96        False          67
#
#      Acaii  Poke Bowl  craft beer  isPartial_y
# ...

# %%
USm = pd.read_csv('US_merged.csv')

# %%
USm["Country"] = "US"

# %%
USm
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  isPartial_x  Bubble Tea  \
# 0    2004-01-01        4        2      3     28        False          15
# 1    2004-02-01        4        2      2     29        False          11
# 2    2004-03-01        4        3      2     28        False          13
# 3    2004-04-01        4        2      2     28        False          15
# 4    2004-05-01        4        3      2     26        False          16
# ..          ...      ...      ...    ...    ...          ...         ...
# 189  2019-10-01       22       25     34     80        False          59
# 190  2019-11-01       21       15     37     83        False          57
# 191  2019-12-01       21       14     39     87        False          58
# 192  2020-01-01       31       14     40     93        False          65
# 193  2020-02-01       30       16     36     96        False          67
#
#      Acaii  Poke Bowl  craft beer  isPartial_y Country
# ...

# %%
pd.concat([USm, DEm], ignore_index=True )
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  isPartial_x  Bubble Tea  \
# 0    2004-01-01        4        2      3     28        False          15
# 1    2004-02-01        4        2      2     29        False          11
# 2    2004-03-01        4        3      2     28        False          13
# 3    2004-04-01        4        2      2     28        False          15
# 4    2004-05-01        4        3      2     26        False          16
# ..          ...      ...      ...    ...    ...          ...         ...
# 383  2019-10-01       28        6     18     90        False          12
# 384  2019-11-01       30        5     17     88        False           8
# 385  2019-12-01       33        4     17     93        False           9
# 386  2020-01-01       45        5     20     99        False          11
# 387  2020-02-01       46        6     17     97        False          11
#
#      Acaii  Poke Bowl  craft beer  isPartial_y Country
# ...

# %%
TOTAL = pd.concat([USm, DEm], ignore_index=True )

# %%
TOTAL = TOTAL.drop(columns='isPartial_x')

# %%
TOTAL.drop(columns='isPartial_y')
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  Bubble Tea  Acaii  Poke Bowl  \
# 0    2004-01-01        4        2      3     28          15      0          0
# 1    2004-02-01        4        2      2     29          11      0          0
# 2    2004-03-01        4        3      2     28          13      0          0
# 3    2004-04-01        4        2      2     28          15      0          0
# 4    2004-05-01        4        3      2     26          16      0          0
# ..          ...      ...      ...    ...    ...         ...    ...        ...
# 383  2019-10-01       28        6     18     90          12      0          4
# 384  2019-11-01       30        5     17     88           8      0          4
# 385  2019-12-01       33        4     17     93           9      0          3
# 386  2020-01-01       45        5     20     99          11      0          4
# 387  2020-02-01       46        6     17     97          11      0          5
#
#      craft beer Country
# ...

# %%
TOTAL.groupby('Country').sum()
# Out:
#          Avocado  Cupcake  Ramen  Sushi  Bubble Tea  Acaii  Poke Bowl  \
# Country
# DE          3033      941    791  10350         869      0         97
# US          2658     3352   2361  12198        5305      9       1368
#
#          craft beer  isPartial_y
# Country
# DE              313        False
# US             4304        False

# %%
TOTALs = TOTAL.groupby('Country').sum()

# %%
TOTALs= TOTALs.reset_index()

# %%
sns.barplot(data=TOTALs,
           x='Country',
           y='Avocado')

# %%
coun=('''AD
AE
AF
AG
AI
AL
AM
AO
AQ
AR
AS
AT
AU
AW
AX
AZ
BA
BB
BD
BE
BF
BG
BH
BI
BJ
BL
BM
BN
BO
BQ
BQ 
BR
BS
BT
BV
BW
BY
BZ
CA
CC
CD
CF
CG
CH
CI
CK
CL
CM
CN
CO
CR
CU
CV
CW
CX
CY
CZ
DE
DJ
DK
DM
DO
DZ
EC
EE
EG
EH
ER
ES
ET
FI
FJ
FK
FM
FO
FR
GA
GB
GD
GE
GF
GG
GH
GI
GL
GM
GN
GP
GQ
GR
GS
GT
GU
GW
GY
HK
HM
HN
HR
HT
HU
ID
IE
IL
IM
IN
IO
IQ
IR
IS
IT
JE
JM
JO
JP
KE
KG
KH
KI
KM
KN
KP
KR
KW
KY
KZ
LA
LB
LC
LI
LK
LR
LS
LT
LU
LV
LY
MA
MC
MD
ME
MF
MG
MH
MK
ML
MM
MN
MO
MP
MQ
MR
MS
MT
MU
MV
MW
MX
MY
MZ
NA
NC
NE
NF
NG
NI
NL
NO
NP
NR
NU
NZ
OM
PA
PE
PF
PG
PH
PK
PL
PM
PN
PR
PS
PT
PW
PY
QA
RE
RO
RS
RU
RW
SA
SB
SC
SD
SE
SG
SH
SI
SJ
SK
SL
SM
SN
SO
SR
SS
ST
SV
SX
SY
SZ
TC
TD
TF
TG
TH
TJ
TK
TL
TM
TN
TO
TR
TT
TV
TW
TZ
UA
UG
UM
US
UY
UZ
VA
VC
VE
VG
VI
VN
VU
WF
WS
YE
YT
ZA
ZM
ZW
''').split()

for country in coun:
    try:
