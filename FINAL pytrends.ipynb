# %%
#API

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list = ["Avocado", "Cupcake", "Ramen", "Sushi"]
pytrends.build_payload(kw_list, cat=0, timeframe='all', geo='US', gprop='')

# %%
df = pytrends.interest_over_time()

# %%
r = pytrends

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
#sns.lineplot(data=kw_list,y="Avocado", x="date")

# %%
type(pytrends.interest_over_time())
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.reset_index()

# %%
df["Country"] = "US"

# %%
df
# Out:
#      index       date  Avocado  Cupcake  Ramen  Sushi isPartial country  \
# 0        0 2004-01-01        4        2      2     24     False      US
# 1        1 2004-02-01        3        2      2     24     False      US
# 2        2 2004-03-01        4        2      1     25     False      US
# 3        3 2004-04-01        3        2      2     22     False      US
# 4        4 2004-05-01        4        2      2     21     False      US
# ..     ...        ...      ...      ...    ...    ...       ...     ...
# 190    190 2019-11-01       18       13     31     69     False      US
# 191    191 2019-12-01       18       12     33     74     False      US
# 192    192 2020-01-01       27       12     34     78     False      US
# 193    193 2020-02-01       25       13     31     82     False      US
# 194    194 2020-03-01       27       14     39    100      True      US
#
#     Country
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
# ..      ...
# ...

# %%
kw_list1 = ["Avocado", "Cupcake", "Ramen"]

# %%
countries = ["US"]

# %%
for country in countries:
    pytrends.build_payload(kw_list, cat=0, timeframe='all', geo=country, gprop='')
    df = pytrends.interest_over_time()
    df["country"] = country
    try:
        df_all = df_all.append(df, ignore=FALSE)
    except:
        df_all = df
        sleep(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-aaf4548df0f2> in <module>
#       5     try:
# ----> 6         df_all = df_all.append(df, ignore=FALSE)
#       7     except:
#
# NameError: name 'df_all' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-aaf4548df0f2> in <module>
#       7     except:
#       8         df_all = df
# ----> 9         sleep(10)
#
# NameError: name 'sleep' is not defined

# %%
sns.lineplot(data=df ,y="Cupcake", x="date")
# Out:
# /Users/konstantin/opt/miniconda3/envs/code_red/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
from pytrends.request import TrendReq

pytrend = TrendReq()

coun=('''AU
FI
GB
HU
IL
JP
NL
NZ
PT
US
''').split()

for country in coun:
    try:
        pytrend.build_payload(kw_list, timeframe='all', geo=country)
        interest_over_time_df = pytrend.interest_over_time()
        interest_over_time_df.to_csv(country+'_holiday.csv')    
    except:
        continue

# %%
pd.read_csv('US_tfood1.csv')
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  isPartial
# 0    2004-01-01        4        2      3     28      False
# 1    2004-02-01        4        2      2     29      False
# 2    2004-03-01        4        3      2     28      False
# 3    2004-04-01        4        2      2     28      False
# 4    2004-05-01        4        3      2     26      False
# ..          ...      ...      ...    ...    ...        ...
# 189  2019-10-01       22       25     34     80      False
# 190  2019-11-01       21       15     37     83      False
# 191  2019-12-01       21       14     39     87      False
# 192  2020-01-01       31       14     40     93      False
# 193  2020-02-01       30       16     36     96      False
#
# [194 rows x 6 columns]

# %%
tf = pd.read_csv('US_tfood2.csv')

# %%
pd.read_csv('US_tfood2.csv')
# Out:
#            date  Bubble Tea  Acaii  Poke Bowl  craft beer  isPartial
# 0    2004-01-01          15      0          0           2      False
# 1    2004-02-01          11      0          0           1      False
# 2    2004-03-01          13      0          0           2      False
# 3    2004-04-01          15      0          0           1      False
# 4    2004-05-01          16      0          0           1      False
# ..          ...         ...    ...        ...         ...        ...
# 189  2019-10-01          59      0         32          33      False
# 190  2019-11-01          57      0         29          33      False
# 191  2019-12-01          58      0         28          36      False
# 192  2020-01-01          65      0         36          30      False
# 193  2020-02-01          67      0         36          34      False
#
# [194 rows x 6 columns]

# %%
US = tf.sum(axis = 0, skipna = True)

# %%
df_us = pd.DataFrame(US[['Bubble Tea','Poke Bowl','craft beer']], columns=['US'])
df_us
# Out:
#               US
# Bubble Tea  5305
# Poke Bowl   1368
# craft beer  4304

# %%
sns.barplot(x=df_us.index,
            y=df_us['US'],
            data=df_us,)

# %%
tf2 = pd.read_csv('DE_tfood2.csv')

# %%
DE = tf2.sum(axis = 0, skipna = True)

# %%
DE
# Out:
# date          2004-01-012004-02-012004-03-012004-04-012004-0...
# Bubble Tea                                                  869
# Acaii                                                         0
# Poke Bowl                                                    97
# craft beer                                                  313
# isPartial                                                 False
# dtype: object

# %%
df_de = pd.DataFrame(DE[['Bubble Tea','Poke Bowl','craft beer']], columns=['DE'])
df_de
# Out:
#              DE
# Bubble Tea  869
# Poke Bowl    97
# craft beer  313

# %%
df_main = df_us.merge(df_de, left_index=True, right_index=True)

# %%
countries = ['DE', 'AU', 'ES']

for country in countries:
    print(f'{country}_tfood1.csv')
# Out:
# DE_tfood1.csv
# AU_tfood1.csv
# ES_tfood1.csv

# %%
a = pd.read_csv("DE_tfood1.csv")
b = pd.read_csv("DE_tfood2.csv")
b = b.dropna(axis=1)
merged = a.merge(b, on='date')
merged.to_csv("DE_merged2.csv", index=False)

# %%
pd.read_csv("DE_merged2.csv")
# Out:
#            date  Avocado  Cupcake  Ramen  Sushi  isPartial_x  Bubble Tea  \
# 0    2004-01-01        4        0      1     25        False           1
# 1    2004-02-01        4        0      1     28        False           0
# 2    2004-03-01        4        1      1     27        False           0
# 3    2004-04-01        5        0      1     25        False           0
# 4    2004-05-01        3        0      1     22        False           0
# ..          ...      ...      ...    ...    ...          ...         ...
# 189  2019-10-01       28        6     18     90        False          12
# 190  2019-11-01       30        5     17     88        False           8
# 191  2019-12-01       33        4     17     93        False           9
# 192  2020-01-01       45        5     20     99        False          11
# 193  2020-02-01       46        6     17     97        False          11
#
#      Acaii  Poke Bowl  craft beer  isPartial_y
# ...

# %%
DEmerged = pd.read_csv("DE_merged2.csv")

# %%
USm = pd.read_csv("US_merged.csv")

# %%
df = df.reset_index()

# %%
USm["Country"] = "US"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-23643e8f1221> in <module>
# ----> 1 USm["Country"] = "US"
#
# NameError: name 'USm' is not defined

# %%
USm.
# Out:
#   File "<ipython-input-36-88abe111fb08>", line 1
#     USm.
#         ^
# SyntaxError: invalid syntax

# %%
USm.sum()['Avocado']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6127d93decfb> in <module>
# ----> 1 USm.sum()['Avocado']
#
# NameError: name 'USm' is not defined

# %%
type(USm.sum())

# %%
c = pd.read_csv("DE_tfood1.csv")
d = pd.read_csv("DE_tfood2.csv")
d = d.dropna(axis=1)
merged = c.merge(d, on='date')
merged.to_csv("DE_merged.csv", index=False)

# %%
DEm = pd.read_csv("DE_merged2.csv")

# %%
DEm = df.reset_index()

# %%
DEm["Country"] = "DE"

# %%
DEm
# Out:
#           date  Avocado  Cupcake  Ramen  Sushi isPartial country Country
# 0   2004-01-01        4        2      2     24     False      US      DE
# 1   2004-02-01        3        2      2     24     False      US      DE
# 2   2004-03-01        4        2      1     25     False      US      DE
# 3   2004-04-01        3        2      2     22     False      US      DE
# 4   2004-05-01        4        2      2     21     False      US      DE
# ..         ...      ...      ...    ...    ...       ...     ...     ...
# 190 2019-11-01       18       13     31     69     False      US      DE
# 191 2019-12-01       18       12     33     74     False      US      DE
# 192 2020-01-01       27       12     34     78     False      US      DE
# 193 2020-02-01       25       13     31     82     False      US      DE
# 194 2020-03-01       27       14     39    100      True      US      DE
#
# [195 rows x 8 columns]

# %%
DEm.sum()['Avocado']
# Out:
# 2290

# %%
pd.concat([USm, DEm], ignore_index=True )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-8a9bff70fd5c> in <module>
# ----> 1 pd.concat([USm, DEm], ignore_index=True )
#
# NameError: name 'USm' is not defined

# %%
MM = pd.concat([USm, DEm], ignore_index=True )

# %%
sns.barplot(data=MM,
           x="Avocado"
           y=US)
# Out:
#   File "<ipython-input-57-13971396d2ea>", line 3
#     y=US)
#     ^
# SyntaxError: invalid syntax

# %%
sns.barplot(x=USm.index,
            y=USm['Avocado'],
            data=USm,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-382fddaa699a> in <module>
# ----> 1 sns.barplot(x=USm.index,
#       2             y=USm['Avocado'],
#       3             data=USm,)
#
# NameError: name 'USm' is not defined

# %%
sns.lineplot(data=USm.sum())

# %%
sns.lineplot(data=USm, y='Avocado', x='date')

# %%
df_main

# %%
sns.barplot()

# %%
sns.lineplot(data=pd.read_csv('US_tfood1.csv') ,y="Cupcake", x="date")
sns.lineplot(data=pd.read_csv('ES_tfood1.csv') ,y="Cupcake", x="date")
sns.lineplot(data=pd.read_csv('DE_tfood1.csv') ,y="Cupcake", x="date")
sns.lineplot(data=pd.read_csv('FR_tfood1.csv') ,y="Cupcake", x="date")

# %%
sns.lineplot(data=pd.read_csv('US_tfood2.csv') ,y="Bubble Tea", x="date")
sns.lineplot(data=pd.read_csv('ES_tfood2.csv') ,y="Bubble Tea", x="date")
sns.lineplot(data=pd.read_csv('DE_tfood2.csv') ,y="Bubble Tea", x="date")
sns.lineplot(data=pd.read_csv('FR_tfood2.csv') ,y="Bubble Tea", x="date")

# %%
sns.lineplot(data=pd.read_csv('US_tfood2.csv') ,y="craft beer", x="date")
sns.lineplot(data=pd.read_csv('ES_tfood2.csv') ,y="craft beer", x="date")
sns.lineplot(data=pd.read_csv('DE_tfood2.csv') ,y="craft beer", x="date")
sns.lineplot(data=pd.read_csv('FR_tfood2.csv') ,y="craft beer", x="date")

# %%
sns.lineplot(data=pd.read_csv('US_tfood2.csv') ,y="Poke Bowl", x="date")
sns.lineplot(data=pd.read_csv('AE_tfood2.csv') ,y="Poke Bowl", x="date")
sns.lineplot(data=pd.read_csv('HK_tfood2.csv') ,y="Poke Bowl", x="date")
sns.lineplot(data=pd.read_csv('DE_tfood2.csv') ,y="Poke Bowl", x="date")

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.lineplot(data=pd.read_csv('AE_tfood1.csv') ,y="Cupcake", x="date", color="blue")
sns.lineplot(data=pd.read_csv('AE_tfood1.csv') ,y="Ramen", x="date", color="red")
sns.lineplot(data=pd.read_csv('AE_tfood1.csv') ,y="Sushi", x="date", color="green")
sns.lineplot(data=pd.read_csv('AE_tfood1.csv') ,y="Avocado", x="date", color="black")
sns.lineplot(data=pd.read_csv('AE_tfood2.csv') ,y="Poke Bowl", x="date", color="yellow")
sns.lineplot(data=pd.read_csv('AE_tfood2.csv') ,y="craft beer", x="date", color="orange")
sns.lineplot(data=pd.read_csv('AE_tfood2.csv') ,y="Acaii", x="date", color="brown")
sns.lineplot(data=pd.read_csv('AE_tfood2.csv') ,y="Bubble Tea", x="date", color="pink")

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=pd.read_csv('US_tfood1.csv') ,y="Cupcake", x="date", color="blue")
sns.lineplot(data=pd.read_csv('CA_tfood1.csv') ,y="Cupcake", x="date", color="red")
sns.lineplot(data=pd.read_csv('AU_tfood1.csv') ,y="Cupcake", x="date", color="green")
sns.lineplot(data=pd.read_csv('DE_tfood1.csv') ,y="Cupcake", x="date", color="black")
sns.lineplot(data=pd.read_csv('NZ_tfood1.csv') ,y="Cupcake", x="date", color="yellow")
sns.lineplot(data=pd.read_csv('IL_tfood1.csv') ,y="Cupcake", x="date", color="orange")
sns.lineplot(data=pd.read_csv('HK_tfood1.csv') ,y="Cupcake", x="date", color="brown")
sns.lineplot(data=pd.read_csv('GB_tfood1.csv') ,y="Cupcake", x="date", color="pink")

# %%
fig, ax = plt.subplots(figsize=(16,9))
sns.lineplot(data=pd.read_csv('US_tfood2.csv') ,y="Poke Bowl", x="date", color="blue")
sns.lineplot(data=pd.read_csv('CA_tfood2.csv') ,y="Poke Bowl", x="date", color="red")
sns.lineplot(data=pd.read_csv('AU_tfood2.csv') ,y="Poke Bowl", x="date", color="green")
sns.lineplot(data=pd.read_csv('DE_tfood2.csv') ,y="Poke Bowl", x="date", color="black")
sns.lineplot(data=pd.read_csv('NZ_tfood2.csv') ,y="Poke Bowl", x="date", color="yellow")
sns.lineplot(data=pd.read_csv('IL_tfood2.csv') ,y="Poke Bowl", x="date", color="orange")
sns.lineplot(data=pd.read_csv('HK_tfood2.csv') ,y="Poke Bowl", x="date", color="brown")
sns.lineplot(data=pd.read_csv('GB_tfood2.csv') ,y="Poke Bowl", x="date", color="pink")

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=pd.read_csv('US_tfood1.csv') ,y="Cupcake", x="date", color="blue")
sns.lineplot(data=pd.read_csv('DE_tfood1.csv') ,y="Cupcake", x="date", color="red")
sns.lineplot(data=pd.read_csv('IT_tfood1.csv') ,y="Cupcake", x="date", color="green")
sns.lineplot(data=pd.read_csv('ES_tfood1.csv') ,y="Cupcake", x="date", color="black")
sns.lineplot(data=pd.read_csv('FR_tfood1.csv') ,y="Cupcake", x="date", color="yellow")
sns.lineplot(data=pd.read_csv('BR_tfood1.csv') ,y="Cupcake", x="date", color="orange")
sns.lineplot(data=pd.read_csv('AU_tfood1.csv') ,y="Cupcake", x="date", color="brown")
sns.lineplot(data=pd.read_csv('GB_tfood1.csv') ,y="Cupcake", x="date", color="pink")

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=pd.read_csv('US_tfood1.csv') ,y="Ramen", x="date", color="blue")
sns.lineplot(data=pd.read_csv('DE_tfood1.csv') ,y="Ramen", x="date", color="red")
sns.lineplot(data=pd.read_csv('IT_tfood1.csv') ,y="Ramen", x="date", color="green")
sns.lineplot(data=pd.read_csv('ES_tfood1.csv') ,y="Ramen", x="date", color="black")
sns.lineplot(data=pd.read_csv('FR_tfood1.csv') ,y="Ramen", x="date", color="yellow")
sns.lineplot(data=pd.read_csv('BR_tfood1.csv') ,y="Ramen", x="date", color="orange")
sns.lineplot(data=pd.read_csv('AU_tfood1.csv') ,y="Ramen", x="date", color="brown")
sns.lineplot(data=pd.read_csv('GB_tfood1.csv') ,y="Ramen", x="date", color="pink")

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=pd.read_csv('US_tfood1.csv') ,y="Sushi", x="date", color="blue")
sns.lineplot(data=pd.read_csv('DE_tfood1.csv') ,y="Sushi", x="date", color="red")
sns.lineplot(data=pd.read_csv('IT_tfood1.csv') ,y="Sushi", x="date", color="green")
sns.lineplot(data=pd.read_csv('ES_tfood1.csv') ,y="Sushi", x="date", color="black")
sns.lineplot(data=pd.read_csv('FR_tfood1.csv') ,y="Sushi", x="date", color="yellow")
sns.lineplot(data=pd.read_csv('BR_tfood1.csv') ,y="Sushi", x="date", color="orange")
sns.lineplot(data=pd.read_csv('AU_tfood1.csv') ,y="Sushi", x="date", color="brown")
sns.lineplot(data=pd.read_csv('GB_tfood1.csv') ,y="Sushi", x="date", color="pink")

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=pd.read_csv('US_tfood1.csv') ,y="Sushi", x="date", color="blue")
sns.lineplot(data=pd.read_csv('DE_tfood1.csv') ,y="Sushi", x="date", color="red")
sns.lineplot(data=pd.read_csv('IT_tfood1.csv') ,y="Sushi", x="date", color="green")
sns.lineplot(data=pd.read_csv('ES_tfood1.csv') ,y="Sushi", x="date", color="black")
sns.lineplot(data=pd.read_csv('FR_tfood1.csv') ,y="Sushi", x="date", color="yellow")
sns.lineplot(data=pd.read_csv('BR_tfood1.csv') ,y="Sushi", x="date", color="orange")
sns.lineplot(data=pd.read_csv('AU_tfood1.csv') ,y="Sushi", x="date", color="brown")
sns.lineplot(data=pd.read_csv('GB_tfood1.csv') ,y="Sushi", x="date", color="pink")

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=pd.read_csv('US_tfood2.csv') ,y="Poke Bowl", x="date", color="blue")
sns.lineplot(data=pd.read_csv('DE_tfood2.csv') ,y="Poke Bowl", x="date", color="red")
sns.lineplot(data=pd.read_csv('IT_tfood2.csv') ,y="Poke Bowl", x="date", color="green")
sns.lineplot(data=pd.read_csv('ES_tfood2.csv') ,y="Poke Bowl", x="date", color="black")
sns.lineplot(data=pd.read_csv('FR_tfood2.csv') ,y="Poke Bowl", x="date", color="yellow")
sns.lineplot(data=pd.read_csv('BR_tfood2.csv') ,y="Poke Bowl", x="date", color="orange")
sns.lineplot(data=pd.read_csv('AU_tfood2.csv') ,y="Poke Bowl", x="date", color="brown")
sns.lineplot(data=pd.read_csv('GB_tfood2.csv') ,y="Poke Bowl", x="date", color="pink")

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=pd.read_csv('US_tfood2.csv') ,y="craft beer", x="date", color="blue")
sns.lineplot(data=pd.read_csv('DE_tfood2.csv') ,y="craft beer", x="date", color="red")
sns.lineplot(data=pd.read_csv('IT_tfood2.csv') ,y="craft beer", x="date", color="green")
sns.lineplot(data=pd.read_csv('ES_tfood2.csv') ,y="craft beer", x="date", color="black")
sns.lineplot(data=pd.read_csv('FR_tfood2.csv') ,y="craft beer", x="date", color="yellow")
sns.lineplot(data=pd.read_csv('BR_tfood2.csv') ,y="craft beer", x="date", color="orange")
sns.lineplot(data=pd.read_csv('CH_tfood2.csv') ,y="craft beer", x="date", color="brown")
sns.lineplot(data=pd.read_csv('GB_tfood2.csv') ,y="craft beer", x="date", color="pink")

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=pd.read_csv('US_tfood2.csv') ,y='Bubble Tea', x="date", color="blue")
sns.lineplot(data=pd.read_csv('DE_tfood2.csv') ,y='Bubble Tea', x="date", color="red")
sns.lineplot(data=pd.read_csv('IT_tfood2.csv') ,y='Bubble Tea', x="date", color="green")
sns.lineplot(data=pd.read_csv('ES_tfood2.csv') ,y='Bubble Tea', x="date", color="black")
sns.lineplot(data=pd.read_csv('FR_tfood2.csv') ,y='Bubble Tea', x="date", color="yellow")
sns.lineplot(data=pd.read_csv('BR_tfood2.csv') ,y='Bubble Tea', x="date", color="orange")
sns.lineplot(data=pd.read_csv('AU_tfood2.csv') ,y='Bubble Tea', x="date", color="brown")
sns.lineplot(data=pd.read_csv('GB_tfood2.csv') ,y='Bubble Tea', x="date", color="pink")
sns.lineplot(data=pd.read_csv('CH_tfood2.csv') ,y='Bubble Tea', x="date")

# %%
pd.read_csv('US_tfood2.csv')
# Out:
#            date  Bubble Tea  Acaii  Poke Bowl  craft beer  isPartial
# 0    2004-01-01          15      0          0           2      False
# 1    2004-02-01          11      0          0           1      False
# 2    2004-03-01          13      0          0           2      False
# 3    2004-04-01          15      0          0           1      False
# 4    2004-05-01          16      0          0           1      False
# ..          ...         ...    ...        ...         ...        ...
# 189  2019-10-01          59      0         32          33      False
# 190  2019-11-01          57      0         29          33      False
# 191  2019-12-01          58      0         28          36      False
# 192  2020-01-01          65      0         36          30      False
# 193  2020-02-01          67      0         36          34      False
#
# [194 rows x 6 columns]
